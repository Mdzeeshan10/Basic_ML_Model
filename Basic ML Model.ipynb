# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\mpasha1\appdata\local\programs\python\python311\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\mpasha1\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\mpasha1\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\mpasha1\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mpasha1\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.1.0)

# %%
df = pd.read_csv('housing.csv')

# %%
 df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
x = df.drop(columns=['MEDV'])

# %%
x
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
d= x.columns.tolist()

# %%
y = df.drop(columns= d)

# %%
# train test split 
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.30, random_state=42)

# %%
x_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 5     0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222
# 116   0.13158   0.0  10.01     0  0.547  6.176  72.5  2.7301    6  432
# 45    0.17142   0.0   6.91     0  0.448  5.682  33.8  5.1004    3  233
# 16    1.05393   0.0   8.14     0  0.538  5.935  29.3  4.4986    4  307
# 468  15.57570   0.0  18.10     0  0.580  5.926  71.0  2.9084   24  666
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 106   0.17120   0.0   8.56     0  0.520  5.836  91.9  2.2110    5  384
# 270   0.29916  20.0   6.96     0  0.464  5.856  42.1  4.4290    3  223
# 348   0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 435  11.16040   0.0  18.10     0  0.740  6.629  94.6  2.1247   24  666
# 102   0.22876   0.0   8.56     0  0.520  6.405  85.4  2.7147    5  384
#
#      PTRATIO       B  LSTAT
# 5       18.7  394.12   5.21
# 116     17.8  393.30  12.04
# 45      17.9  396.90  10.21
# 16      21.0  386.85   6.58
# 468     20.2  368.74  18.13
# ..       ...     ...    ...
# 106     20.9  395.67  18.66
# 270     18.6  388.65  13.00
# 348     17.0  390.94   5.99
# 435     20.2  109.85  23.27
# 102     20.9   70.80  10.63
#
# [354 rows x 13 columns]

# %%
y_train
# Out:
#      MEDV
# 5    28.7
# 116  21.2
# 45   19.3
# 16   23.1
# 468  19.1
# ..    ...
# 106  19.5
# 270  21.1
# 348  24.5
# 435  13.4
# 102  18.6
#
# [354 rows x 1 columns]

# %%
lr=LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.predict(x_test)
# Out:
# array([[29.07194308],
#        [36.10639164],
#        [13.75908538],
#        [24.55744957],
#        [18.58215236],
#        [22.94545403],
#        [17.61572573],
#        [13.57141932],
#        [22.97718032],
#        [20.46870847],
#        [24.91525464],
#        [18.92026211],
#        [-4.28131071],
#        [21.26198266],
#        [19.45123791],
#        [25.57824627],
#        [20.56099819],
#        [ 6.4519857 ],
#        [40.84555721],
#        [17.5183465 ],
#        [27.20340972],
#        [30.35192656],
#        [11.45511759],
#        [23.53334055],
#        [18.12427476],
#        [16.39147632],
#        [22.42817373],
#        [15.28000133],
#        [22.39251096],
#        [19.10854144],
#        [22.97657219],
#        [24.88682244],
#        [25.30713064],
#        [18.22846804],
#        [16.94776851],
#        [17.28601894],
#        [30.56759672],
#        [20.16097176],
#        [23.49428992],
#        [24.04295712],
#        [14.01320787],
#        [32.70905124],
#        [43.18949844],
#        [17.42153786],
#        [27.1190194 ],
#        [17.21225183],
#        [14.28275814],
#        [25.20148859],
#        [20.16719441],
#        [30.00384338],
#        [21.58679568],
#        [34.33123186],
#        [15.83288129],
#        [25.59413475],
#        [39.31792393],
#        [22.22225914],
#        [18.740485  ],
#        [33.43563311],
#        [24.78456674],
#        [13.39891261],
#        [22.55408869],
#        [31.15264947],
#        [31.23411512],
#        [16.17801106],
#        [20.54605423],
#        [17.00587718],
#        [20.30445783],
#        [26.03576297],
#        [31.35762569],
#        [12.68725581],
#        [20.42320032],
#        [27.09887315],
#        [11.51474683],
#        [16.59488462],
#        [23.35699818],
#        [ 6.55162319],
#        [21.43482591],
#        [42.03193124],
#        [18.47682833],
#        [ 8.22386687],
#        [20.78483633],
#        [13.70756369],
#        [21.69580887],
#        [ 9.89116643],
#        [23.28133979],
#        [31.71383523],
#        [19.04860533],
#        [25.11783401],
#        [29.08105546],
#        [19.36163954],
#        [25.61669307],
#        [ 6.89562363],
#        [19.41013402],
#        [14.78359641],
#        [14.28190734],
#        [20.06191566],
#        [24.94331333],
#        [ 1.71851807],
#        [14.52079384],
#        [16.96071981],
#        [22.16853423],
#        [23.9669302 ],
#        [11.54272738],
#        [19.29748321],
#        [23.33888   ],
#        [13.1752861 ],
#        [18.40613603],
#        [24.66786913],
#        [20.61872907],
#        [24.85686978],
#        [ 8.81976005],
#        [19.85268454],
#        [21.55509929],
#        [27.76552111],
#        [32.3995325 ],
#        [15.96090435],
#        [34.72440464],
#        [13.38668561],
#        [20.62662054],
#        [28.42717057],
#        [16.3285756 ],
#        [24.20633547],
#        [ 6.14779852],
#        [23.69043261],
#        [25.20386628],
#        [22.86952447],
#        [25.27380082],
#        [33.88787321],
#        [20.10375923],
#        [38.79756966],
#        [14.61706633],
#        [24.25249073],
#        [18.05923295],
#        [20.71548315],
#        [ 9.71844139],
#        [21.527283  ],
#        [22.1667232 ],
#        [33.10919806],
#        [31.55871004],
#        [15.67833832],
#        [16.91140135],
#        [29.11309844],
#        [25.53056512],
#        [17.06042754],
#        [ 7.37816361],
#        [27.03977365],
#        [22.36600228],
#        [17.29558059],
#        [13.80628535],
#        [39.81461867],
#        [17.03141861],
#        [18.12695239]])

# %%
## standardizing the dataset
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler = StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.41425879, -0.50512499, -1.29214218, ...,  0.18727079,
#          0.39651419, -1.01531611],
#        [-0.40200818, -0.50512499, -0.16208345, ..., -0.21208981,
#          0.3870674 , -0.05366252],
#        [-0.39721053, -0.50512499, -0.60948856, ..., -0.16771641,
#          0.42854113, -0.31132373],
#        ...,
#        [-0.41604586,  3.03838247, -1.3166773 , ..., -0.56707702,
#          0.35987906, -0.90549329],
#        [ 0.92611293, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.87841346,  1.52750437],
#        [-0.39030549, -0.50512499, -0.37135358, ...,  1.16348561,
#         -3.32828832, -0.25218837]])

# %%
xy=scaler.transform(x_test)

# %%
ch = scaler.fit_transform(x_test)

# %%
ch
# Out:
# array([[-0.41814319, -0.45257245, -1.06299571, ..., -1.2129824 ,
#          0.45712276, -0.5785895 ],
#        [-0.42197518,  1.15375592, -0.70943587, ..., -0.67841202,
#          0.47107234, -1.34619278],
#        [-0.41662948, -0.45257245,  2.48608589, ...,  0.65801394,
#          0.40341687,  0.67938829],
#        ...,
#        [-0.37095894, -0.45257245, -0.74089671, ..., -0.78532609,
#          0.32260895, -1.19295074],
#        [ 0.17707231, -0.45257245,  1.04188384, ...,  0.71147097,
#         -2.48534188,  0.42166305],
#        [ 0.64807771, -0.45257245,  1.04188384, ...,  0.71147097,
#          0.38757414,  0.45231146]])

# %%
x.cloumn.tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[279], line 1
# ----> 1 x.cloumn.tolist()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'cloumn'

# %%
ch_df = pd.DataFrame(ch, columns=x.columns.tolist())

# %%
ch_df
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.418143 -0.452572 -1.062996 -0.250873 -0.341167  0.347776  0.548969
# 1   -0.421975  1.153756 -0.709436  3.986087 -0.896224  0.871874 -1.202404
# 2   -0.416629 -0.452572  2.486086 -0.250873  0.531066 -0.315776  1.051805
# 3   -0.418158 -0.452572 -0.050257 -0.250873 -1.195779 -0.190115 -2.060987
# 4    0.123843 -0.452572  1.041884 -0.250873  1.447351  0.165414  0.812360
# ..        ...       ...       ...       ...       ...       ...       ...
# 147  0.626319 -0.452572  1.041884 -0.250873  1.685233  0.332451  0.997075
# 148 -0.320918 -0.452572 -0.450259 -0.250873 -0.094475 -0.576292  1.092853
# 149 -0.370959 -0.452572 -0.740897 -0.250873 -0.394029  3.886204  0.511342
# 150  0.177072 -0.452572  1.041884 -0.250873  1.447351  0.378425  0.678954
# 151  0.648078 -0.452572  1.041884 -0.250873  1.685233  0.094921  0.976551
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT
# 0   -0.591728 -0.543039 -0.664493 -1.212982  0.457123 -0.578589
# 1    0.104383 -0.655955 -0.907136 -0.678412  0.471072 -1.346193
# 2   -0.970205 -0.655955  1.733048  0.658014  0.403417  0.679388
# 3    0.692719 -0.655955 -0.612498  0.176901  0.411388 -1.068964
# 4   -0.726982  1.602373  1.473074  0.711471  0.353398  0.567940
# ..        ...       ...       ...       ...       ...       ...
# 147 -0.874394  1.602373  1.473074  0.711471  0.362066  0.881389
# 148  0.112942 -0.655955 -0.600944  1.139127  0.447557  0.931541
# 149 -0.471065 -0.204290 -0.600944 -0.785326  0.322609 -1.192951
# 150 -0.752466  1.602373  1.473074  0.711471 -2.485342  0.421663
# 151 -0.809758  1.602373  1.473074  0.711471  0.387574  0.452311
#
# [152 rows x 13 columns]

# %%
xy
# Out:
# array([[-0.406801  , -0.50512499, -1.02225586, ..., -0.74457062,
#          0.41241246, -0.47605794],
#        [-0.41105674,  1.26662874, -0.68165068, ..., -0.30083661,
#          0.42854113, -1.25185755],
#        [-0.4051199 , -0.50512499,  2.39678516, ...,  0.8084984 ,
#          0.35031705,  0.79535229],
#        ...,
#        [-0.35439903, -0.50512499, -0.71195877, ..., -0.38958342,
#          0.25688594, -1.09697922],
#        [ 0.25423453, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.98970133,  0.53487511],
#        [ 0.77732457, -0.50512499,  1.00549958, ...,  0.8528718 ,
#          0.33199949,  0.56585078]])

# %%
from sklearn.linear_model import LinearRegression
##cross validation
from sklearn.model_selection import cross_val_score

# %%
regression=LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
mse=cross_val_score(regression,x_train,y_train,scoring='neg_mean_squared_error',cv=10)

# %%
np.mean(mse)
# Out:
# -25.55066079166079

# %%
##prediction 
reg_pred=regression.predict(x_test)

# %%
x_test
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 173  0.09178   0.0   4.05     0  0.510  6.416   84.1  2.6463    5  296
# 274  0.05644  40.0   6.41     1  0.447  6.758   32.9  4.0776    4  254
# 491  0.10574   0.0  27.74     0  0.609  5.983   98.8  1.8681    4  711
# 72   0.09164   0.0  10.81     0  0.413  6.065    7.8  5.2873    4  305
# 452  5.09017   0.0  18.10     0  0.713  6.297   91.8  2.3682   24  666
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 441  9.72418   0.0  18.10     0  0.740  6.406   97.2  2.0651   24  666
# 23   0.98843   0.0   8.14     0  0.538  5.813  100.0  4.0952    4  307
# 225  0.52693   0.0   6.20     0  0.504  8.725   83.0  2.8944    8  307
# 433  5.58107   0.0  18.10     0  0.713  6.436   87.9  2.3158   24  666
# 447  9.92485   0.0  18.10     0  0.740  6.251   96.6  2.1980   24  666
#
#      PTRATIO       B  LSTAT
# 173     16.6  395.50   9.04
# 274     17.6  396.90   3.53
# 491     20.1  390.11  18.07
# 72      19.2  390.91   5.52
# 452     20.2  385.09  17.27
# ..       ...     ...    ...
# 441     20.2  385.96  19.52
# 23      21.0  394.54  19.88
# 225     17.4  382.00   4.63
# 433     20.2  100.19  16.22
# 447     20.2  388.52  16.44
#
# [152 rows x 13 columns]

# %%
ch_test = x_test.copy()

# %%
pd.DataFrame(reg_pred)[0]
# Out:
# 0      28.648960
# 1      36.495014
# 2      15.411193
# 3      25.403213
# 4      18.855280
#          ...
# 147    17.403672
# 148    13.385941
# 149    39.983425
# 150    16.682863
# 151    18.285618
# Name: 0, Length: 152, dtype: float64

# %%
x.columns.tolist()
# Out:
# ['CRIM',
#  'ZN',
#  'INDUS',
#  'CHAS',
#  'NOX',
#  'RM',
#  'AGE',
#  'DIS',
#  'RAD',
#  'TAX',
#  'PTRATIO',
#  'B',
#  'LSTAT']

# %%
ch_test
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 173  0.09178   0.0   4.05     0  0.510  6.416   84.1  2.6463    5  296
# 274  0.05644  40.0   6.41     1  0.447  6.758   32.9  4.0776    4  254
# 491  0.10574   0.0  27.74     0  0.609  5.983   98.8  1.8681    4  711
# 72   0.09164   0.0  10.81     0  0.413  6.065    7.8  5.2873    4  305
# 452  5.09017   0.0  18.10     0  0.713  6.297   91.8  2.3682   24  666
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 441  9.72418   0.0  18.10     0  0.740  6.406   97.2  2.0651   24  666
# 23   0.98843   0.0   8.14     0  0.538  5.813  100.0  4.0952    4  307
# 225  0.52693   0.0   6.20     0  0.504  8.725   83.0  2.8944    8  307
# 433  5.58107   0.0  18.10     0  0.713  6.436   87.9  2.3158   24  666
# 447  9.92485   0.0  18.10     0  0.740  6.251   96.6  2.1980   24  666
#
#      PTRATIO       B  LSTAT  pred_test
# 173     16.6  395.50   9.04        NaN
# 274     17.6  396.90   3.53        NaN
# 491     20.1  390.11  18.07        NaN
# 72      19.2  390.91   5.52  10.943170
# 452     20.2  385.09  17.27        NaN
# ..       ...     ...    ...        ...
# 441     20.2  385.96  19.52        NaN
# 23      21.0  394.54  19.88  24.020831
# 225     17.4  382.00   4.63        NaN
# 433     20.2  100.19  16.22        NaN
# 447     20.2  388.52  16.44        NaN
#
# [152 rows x 14 columns]

# %%
ch_test['pred_test']= pd.DataFrame(reg_pred)[0]

# %%
ch_test = ch_test.reset_index(drop=True)

# %%
ch_test
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0    0.09178   0.0   4.05     0  0.510  6.416   84.1  2.6463    5  296
# 1    0.05644  40.0   6.41     1  0.447  6.758   32.9  4.0776    4  254
# 2    0.10574   0.0  27.74     0  0.609  5.983   98.8  1.8681    4  711
# 3    0.09164   0.0  10.81     0  0.413  6.065    7.8  5.2873    4  305
# 4    5.09017   0.0  18.10     0  0.713  6.297   91.8  2.3682   24  666
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 147  9.72418   0.0  18.10     0  0.740  6.406   97.2  2.0651   24  666
# 148  0.98843   0.0   8.14     0  0.538  5.813  100.0  4.0952    4  307
# 149  0.52693   0.0   6.20     0  0.504  8.725   83.0  2.8944    8  307
# 150  5.58107   0.0  18.10     0  0.713  6.436   87.9  2.3158   24  666
# 151  9.92485   0.0  18.10     0  0.740  6.251   96.6  2.1980   24  666
#
#      PTRATIO       B  LSTAT  pred_test
# 0       16.6  395.50   9.04  28.648960
# 1       17.6  396.90   3.53  36.495014
# 2       20.1  390.11  18.07  15.411193
# 3       19.2  390.91   5.52  25.403213
# 4       20.2  385.09  17.27  18.855280
# ..       ...     ...    ...        ...
# 147     20.2  385.96  19.52  17.403672
# 148     21.0  394.54  19.88  13.385941
# 149     17.4  382.00   4.63  39.983425
# 150     20.2  100.19  16.22  16.682863
# 151     20.2  388.52  16.44  18.285618
#
# [152 rows x 14 columns]

# %%
reg_pred.shape
# Out:
# (152, 1)

# %%
import seaborn as sns
p = sns.displot(reg_pred-y_test,kind='kde')

# %%
from sklearn.metrics import r2_score, mean_squared_error,mean_absolute_error

# %%
score=mean_absolute_error(reg_pred,y_test)

# %%
score
# Out:
# 0.6693702691495593

# %%
np.sqrt(mean_squared_error(reg_pred,y_test))
# Out:
# 4.6386899261728205

# %%
y_test
# Out:
#      MEDV
# 173  23.6
# 274  32.4
# 491  13.6
# 72   22.8
# 452  16.1
# ..    ...
# 441  17.1
# 23   14.5
# 225  50.0
# 433  14.3
# 447  12.6
#
# [152 rows x 1 columns]

# %%
k=k+1
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[321], line 1
# ----> 1 k= int(None)
#       2 k=k+1
#       3 print(s)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error,mean_absolute_error
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from datetime import datetime



class Zee_Auto_LR_Model:
    
    
    def __init__(self):
        self.time = 0
        
    def fit(self, x, y, testsize, scale):
        
        self.time = datetime.now().strftime("D%Y-%m-%dT%H-%M-%S")
        
        # Spliting the data in training and testing format
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=testsize, random_state=42)
        
        # Scale the train data as per requirement standard ya minmax format
        
        if "standard" == scale:
            scaler = StandardScaler()
            x_train=scaler.fit_transform(x_train)
            x_test=scaler.transform(x_test)
            
            
        elif "minmax" == scale:
            scaler = MinMaxScaler()
            x_train=scaler.fit_transform(x_train)
            x_test=scaler.transform(x_test)
            
        
            
        else:
            x_train = x_train
            x_test = x_test
            
        # Applying the Linear Regression Model to to fit provid training x and y    
        regression=LinearRegression()
        regression.fit(x_train,y_train)
        
        ##prediction to x test data set
        reg_pred=regression.predict(x_test)
        
        test_df = pd.DataFrame(x_test, columns= x.columns.tolist())
        test_df = test_df.reset_index(drop=True)
        pred_df = pd.DataFrame(reg_pred)
        pred_df = pred_df.reset_index(drop=True)
        
        test_df['pred_test'] = pred_df[0]
        test_df['y_test'] = y_test.reset_index(drop=True)
        test_df.to_csv(f"pred_test_{str(self.time)}.csv")
        
        r2 = r2_score(reg_pred,y_test)
        mae = mean_absolute_error(reg_pred,y_test)
        mse = mean_squared_error(reg_pred,y_test)
        rmse = np.sqrt(mean_squared_error(reg_pred,y_test))
        
        # list of Matrics, Value
        nme = ["R2_Sore", "MAE", "MSE", "RMSE"]
        value = [r2, mae, mse, rmse]
         
        # dictionary of lists
        dict = {'Matrics': nme, 'Value': value}
             
        matrics_df = pd.DataFrame(dict)
        
        matrics_df.to_csv(f"Matrics_{str(self.time)}.csv")
        
        

        with open(f"Zee_Auto_model_LR_{str(self.time)}.pkl", "wb") as f:
            pickle.dump(regression, f)
         
        return test_df, matrics_df

# %%
y_test.reset_index(drop=True)
# Out:
#      MEDV
# 0    23.6
# 1    32.4
# 2    13.6
# 3    22.8
# 4    16.1
# ..    ...
# 147  17.1
# 148  14.5
# 149  50.0
# 150  14.3
# 151  12.6
#
# [152 rows x 1 columns]

# %%
test_df = pd.DataFrame(x_test, columns= x.columns.tolist())
test_df = test_df.reset_index(drop=True)
test_df['y_test'] = y_test.reset_index(drop=True)
test_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0    0.09178   0.0   4.05     0  0.510  6.416   84.1  2.6463    5  296
# 1    0.05644  40.0   6.41     1  0.447  6.758   32.9  4.0776    4  254
# 2    0.10574   0.0  27.74     0  0.609  5.983   98.8  1.8681    4  711
# 3    0.09164   0.0  10.81     0  0.413  6.065    7.8  5.2873    4  305
# 4    5.09017   0.0  18.10     0  0.713  6.297   91.8  2.3682   24  666
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 147  9.72418   0.0  18.10     0  0.740  6.406   97.2  2.0651   24  666
# 148  0.98843   0.0   8.14     0  0.538  5.813  100.0  4.0952    4  307
# 149  0.52693   0.0   6.20     0  0.504  8.725   83.0  2.8944    8  307
# 150  5.58107   0.0  18.10     0  0.713  6.436   87.9  2.3158   24  666
# 151  9.92485   0.0  18.10     0  0.740  6.251   96.6  2.1980   24  666
#
#      PTRATIO       B  LSTAT  y_test
# 0       16.6  395.50   9.04    23.6
# 1       17.6  396.90   3.53    32.4
# 2       20.1  390.11  18.07    13.6
# 3       19.2  390.91   5.52    22.8
# 4       20.2  385.09  17.27    16.1
# ..       ...     ...    ...     ...
# 147     20.2  385.96  19.52    17.1
# 148     21.0  394.54  19.88    14.5
# 149     17.4  382.00   4.63    50.0
# 150     20.2  100.19  16.22    14.3
# 151     20.2  388.52  16.44    12.6
#
# [152 rows x 14 columns]

# %%
y
# Out:
#      MEDV
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
mymodel1 = Zee_Auto_LR_Model()

# %%
mymodel1.fit(x, y, 0.30, "minmax")
# Out:
# (         CRIM        ZN     INDUS  CHAS       NOX        RM       AGE  \
#  0    0.000930  0.000000  0.107049   0.0  0.257202  0.519219  0.836251
#  1    0.000533  0.421053  0.196005   1.0  0.127572  0.588774  0.308960
#  2    0.001087  0.000000  1.000000   0.0  0.460905  0.431157  0.987642
#  3    0.000928  0.000000  0.361855   0.0  0.057613  0.447834  0.050463
#  4    0.057112  0.000000  0.636638   0.0  0.674897  0.495017  0.915551
#  ..        ...       ...       ...   ...       ...       ...       ...
#  147  0.109199  0.000000  0.636638   0.0  0.730453  0.517185  0.971164
#  148  0.011008  0.000000  0.261214   0.0  0.314815  0.396583  1.000000
#  149  0.005821  0.000000  0.188089   0.0  0.244856  0.988814  0.824923
#  150  0.062630  0.000000  0.636638   0.0  0.674897  0.523287  0.875386
#  151  0.111455  0.000000  0.636638   0.0  0.730453  0.485662  0.964985
#
#            DIS       RAD       TAX   PTRATIO         B     LSTAT  pred_test  \
#  0    0.137921  0.173913  0.208015  0.425532  0.996470  0.201711  28.648960
#  1    0.268076  0.130435  0.127863  0.531915  1.000000  0.049669  36.495014
#  2    0.067155  0.130435  1.000000  0.797872  0.982879  0.450883  15.411193
#  3    0.378079  0.130435  0.225191  0.702128  0.984896  0.104581  25.403213
#  4    0.112632  1.000000  0.914122  0.808511  0.970220  0.428808  18.855280
#  ..        ...       ...       ...       ...       ...       ...        ...
#  147  0.085069  1.000000  0.914122  0.808511  0.972414  0.490894  17.403672
#  148  0.269676  0.130435  0.229008  0.893617  0.994049  0.500828  13.385941
#  149  0.160482  0.304348  0.229008  0.510638  0.962429  0.080022  39.983425
#  150  0.107867  1.000000  0.914122  0.808511  0.251828  0.399834  16.682863
#  151  0.097155  1.000000  0.914122  0.808511  0.978869  0.405905  18.285618
#
#       y_test
#  0      23.6
#  1      32.4
#  2      13.6
#  3      22.8
#  4      16.1
#  ..      ...
#  147    17.1
#  148    14.5
#  149    50.0
#  150    14.3
#  151    12.6
#
#  [152 rows x 15 columns],
#     Matrics      Value
#  0  R2_Sore   0.669370
#  1      MAE   3.162710
#  2      MSE  21.517444
#  3     RMSE   4.638690)

# %%
model_lr = Zee_Auto_LR_Model()

# %%
model_lr.fit(x, y, 0.30, 'standard')
# Out:
# (         CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
#  0   -0.406801 -0.505125 -1.022256 -0.281546 -0.405218  0.125771  0.553831
#  1   -0.411057  1.266629 -0.681651  3.551814 -0.945403  0.601965 -1.299478
#  2   -0.405120 -0.505125  2.396785 -0.281546  0.443643 -0.477130  1.085934
#  3   -0.406818 -0.505125 -0.046624 -0.281546 -1.236931 -0.362955 -2.208034
#  4    0.195119 -0.505125  1.005500 -0.281546  1.335376 -0.039923  0.832552
#  ..        ...       ...       ...       ...       ...       ...       ...
#  147  0.753159 -0.505125  1.005500 -0.281546  1.566884  0.111847  1.028018
#  148 -0.298824 -0.505125 -0.431970 -0.281546 -0.165136 -0.713835  1.129371
#  149 -0.354399 -0.505125 -0.711959 -0.281546 -0.456664  3.340777  0.514014
#  150  0.254235 -0.505125  1.005500 -0.281546  1.335376  0.153618  0.691381
#  151  0.777325 -0.505125  1.005500 -0.281546  1.566884 -0.103972  1.006299
#
#            DIS       RAD       TAX   PTRATIO         B     LSTAT  pred_test  \
#  0   -0.527348 -0.514369 -0.667776 -0.744571  0.412412 -0.476058  28.648960
#  1    0.146831 -0.630274 -0.920352 -0.300837  0.428541 -1.251858  36.495014
#  2   -0.893900 -0.630274  1.827911  0.808498  0.350317  0.795352  15.411193
#  3    0.716631 -0.630274 -0.613653  0.409138  0.359533 -0.971669  25.403213
#  4   -0.658340  1.687825  1.557294  0.852872  0.292484  0.682714  18.855280
#  ..        ...       ...       ...       ...       ...       ...        ...
#  147 -0.801108  1.687825  1.557294  0.852872  0.302507  0.999510  17.403672
#  148  0.155121 -0.630274 -0.601625  1.207859  0.401353  1.050198  13.385941
#  149 -0.410487 -0.166654 -0.601625 -0.389583  0.256886 -1.096979  39.983425
#  150 -0.683022  1.687825  1.557294  0.852872 -2.989701  0.534875  16.682863
#  151 -0.738509  1.687825  1.557294  0.852872  0.331999  0.565851  18.285618
#
#       y_test
#  0      23.6
#  1      32.4
#  2      13.6
#  3      22.8
#  4      16.1
#  ..      ...
#  147    17.1
#  148    14.5
#  149    50.0
#  150    14.3
#  151    12.6
#
#  [152 rows x 15 columns],
#     Matrics      Value
#  0  R2_Sore   0.669370
#  1      MAE   3.162710
#  2      MSE  21.517444
#  3     RMSE   4.638690)

# %%
x
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
y
# Out:
#      MEDV
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
df1 = pd.read_csv('Salary_Data.csv')

# %%
df1
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x1 = df1.drop(columns=['Salary'])

# %%
y1 = df1.drop(columns=['YearsExperience'])

# %%
y1
# Out:
#       Salary
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# 5    56642.0
# 6    60150.0
# 7    54445.0
# 8    64445.0
# 9    57189.0
# 10   63218.0
# 11   55794.0
# 12   56957.0
# 13   57081.0
# 14   61111.0
# 15   67938.0
# 16   66029.0
# 17   83088.0
# 18   81363.0
# 19   93940.0
# 20   91738.0
# 21   98273.0
# 22  101302.0
# 23  113812.0
# 24  109431.0
# 25  105582.0
# 26  116969.0
# 27  112635.0
# 28  122391.0
# 29  121872.0

# %%
mode_salary = Zee_Auto_LR_Model()

# %%
mode_salary.fit(x, y, 0.30, 'standard')
# Out:
# (         CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
#  0   -0.406801 -0.505125 -1.022256 -0.281546 -0.405218  0.125771  0.553831
#  1   -0.411057  1.266629 -0.681651  3.551814 -0.945403  0.601965 -1.299478
#  2   -0.405120 -0.505125  2.396785 -0.281546  0.443643 -0.477130  1.085934
#  3   -0.406818 -0.505125 -0.046624 -0.281546 -1.236931 -0.362955 -2.208034
#  4    0.195119 -0.505125  1.005500 -0.281546  1.335376 -0.039923  0.832552
#  ..        ...       ...       ...       ...       ...       ...       ...
#  147  0.753159 -0.505125  1.005500 -0.281546  1.566884  0.111847  1.028018
#  148 -0.298824 -0.505125 -0.431970 -0.281546 -0.165136 -0.713835  1.129371
#  149 -0.354399 -0.505125 -0.711959 -0.281546 -0.456664  3.340777  0.514014
#  150  0.254235 -0.505125  1.005500 -0.281546  1.335376  0.153618  0.691381
#  151  0.777325 -0.505125  1.005500 -0.281546  1.566884 -0.103972  1.006299
#
#            DIS       RAD       TAX   PTRATIO         B     LSTAT  pred_test  \
#  0   -0.527348 -0.514369 -0.667776 -0.744571  0.412412 -0.476058  28.648960
#  1    0.146831 -0.630274 -0.920352 -0.300837  0.428541 -1.251858  36.495014
#  2   -0.893900 -0.630274  1.827911  0.808498  0.350317  0.795352  15.411193
#  3    0.716631 -0.630274 -0.613653  0.409138  0.359533 -0.971669  25.403213
#  4   -0.658340  1.687825  1.557294  0.852872  0.292484  0.682714  18.855280
#  ..        ...       ...       ...       ...       ...       ...        ...
#  147 -0.801108  1.687825  1.557294  0.852872  0.302507  0.999510  17.403672
#  148  0.155121 -0.630274 -0.601625  1.207859  0.401353  1.050198  13.385941
#  149 -0.410487 -0.166654 -0.601625 -0.389583  0.256886 -1.096979  39.983425
#  150 -0.683022  1.687825  1.557294  0.852872 -2.989701  0.534875  16.682863
#  151 -0.738509  1.687825  1.557294  0.852872  0.331999  0.565851  18.285618
#
#       y_test
#  0      23.6
#  1      32.4
#  2      13.6
#  3      22.8
#  4      16.1
#  ..      ...
#  147    17.1
#  148    14.5
#  149    50.0
#  150    14.3
#  151    12.6
#
#  [152 rows x 15 columns],
#     Matrics      Value
#  0  R2_Sore   0.669370
#  1      MAE   3.162710
#  2      MSE  21.517444
#  3     RMSE   4.638690)

# %%
y_test.isnull().sum()
# Out:
# MEDV    0
# dtype: int64

# %%
mo= Zee_Auto_LR_Model()

# %%
mo.fit(x1,y1,0.30,'standard')
# Out:
# (   YearsExperience      pred_test    y_test
#  0         1.744941  115573.622884  112635.0
#  1         0.024405   71679.938782   67938.0
#  2         1.232441  102498.908470  113812.0
#  3         0.170833   75415.571471   83088.0
#  4        -0.597917   55803.499851   64445.0
#  5        -0.414881   60473.040713   57189.0
#  6         2.001191  122110.980090  122391.0
#  7         1.415476  107168.449332  109431.0
#  8        -0.305060   63274.765230   56957.0,
#     Matrics         Value
#  0  R2_Sore  9.357877e-01
#  1      MAE  5.161329e+03
#  2      MSE  3.778466e+07
#  3     RMSE  6.146923e+03)

# %%
x
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
y
# Out:
#      MEDV
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
mode_ad = Zee_Auto_LR_Model()

# %%
mode_ad.fit(x, y, 0.30, "standard")
# Out:
# (         CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
#  0   -0.406801 -0.505125 -1.022256 -0.281546 -0.405218  0.125771  0.553831
#  1   -0.411057  1.266629 -0.681651  3.551814 -0.945403  0.601965 -1.299478
#  2   -0.405120 -0.505125  2.396785 -0.281546  0.443643 -0.477130  1.085934
#  3   -0.406818 -0.505125 -0.046624 -0.281546 -1.236931 -0.362955 -2.208034
#  4    0.195119 -0.505125  1.005500 -0.281546  1.335376 -0.039923  0.832552
#  ..        ...       ...       ...       ...       ...       ...       ...
#  147  0.753159 -0.505125  1.005500 -0.281546  1.566884  0.111847  1.028018
#  148 -0.298824 -0.505125 -0.431970 -0.281546 -0.165136 -0.713835  1.129371
#  149 -0.354399 -0.505125 -0.711959 -0.281546 -0.456664  3.340777  0.514014
#  150  0.254235 -0.505125  1.005500 -0.281546  1.335376  0.153618  0.691381
#  151  0.777325 -0.505125  1.005500 -0.281546  1.566884 -0.103972  1.006299
#
#            DIS       RAD       TAX   PTRATIO         B     LSTAT  pred_test  \
#  0   -0.527348 -0.514369 -0.667776 -0.744571  0.412412 -0.476058  28.648960
#  1    0.146831 -0.630274 -0.920352 -0.300837  0.428541 -1.251858  36.495014
#  2   -0.893900 -0.630274  1.827911  0.808498  0.350317  0.795352  15.411193
#  3    0.716631 -0.630274 -0.613653  0.409138  0.359533 -0.971669  25.403213
#  4   -0.658340  1.687825  1.557294  0.852872  0.292484  0.682714  18.855280
#  ..        ...       ...       ...       ...       ...       ...        ...
#  147 -0.801108  1.687825  1.557294  0.852872  0.302507  0.999510  17.403672
#  148  0.155121 -0.630274 -0.601625  1.207859  0.401353  1.050198  13.385941
#  149 -0.410487 -0.166654 -0.601625 -0.389583  0.256886 -1.096979  39.983425
#  150 -0.683022  1.687825  1.557294  0.852872 -2.989701  0.534875  16.682863
#  151 -0.738509  1.687825  1.557294  0.852872  0.331999  0.565851  18.285618
#
#       y_test
#  0      23.6
#  1      32.4
#  2      13.6
#  3      22.8
#  4      16.1
#  ..      ...
#  147    17.1
#  148    14.5
#  149    50.0
#  150    14.3
#  151    12.6
#
#  [152 rows x 15 columns],
#     Matrics      Value
#  0  R2_Sore   0.669370
#  1      MAE   3.162710
#  2      MSE  21.517444
#  3     RMSE   4.638690)

# %%
import time

# ts stores the time in seconds
ts = time.time()

# print the current timestamp
print(ts)
# Out:
# 1693288668.715199

# %%
from datetime import datetime

timestamp = datetime.now()
print('timestamp:', str(timestamp))
# Out:
# timestamp: 2023-08-29 11:38:45.130326
